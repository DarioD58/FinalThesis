# %%
import os
import torch.optim as optim
from torch import nn
import torch
import torchvision
import torchvision.transforms as transforms
import math
from PIL import Image
from torchvision.datasets import CIFAR100
import matplotlib.pyplot as plt
import numpy as np
import pickle
from torchsummary import summary
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#All the parameters
epoch = 100
epoch_consolidation = 50
epoch_fine_tune = 15
lr = 0.01
lr_cons = 0.0001
lr_finetune = 0.0001
weight_decay = 0.0001
momentum = 0.9
gamma = 0.1
resnet_type = 5
batch_size = 128
classes_batch_size = 5
K = 2000
SAVE_DIR = '/content/drive/MyDrive/Zavrsni'
device = torch.device('cuda')

# %%
class ResidualBlock(nn.Module):
  def __init__(self, channel_num, stride, downsample_layer = None):
    super(ResidualBlock, self).__init__()

    self.downsample = downsample_layer
    
    self.conv1 = nn.Sequential(
        nn.Conv2d(int(channel_num/stride), channel_num, 3, stride, padding=1),
        nn.BatchNorm2d(channel_num),
        nn.ReLU(),
    )
    self.conv2 = nn.Sequential(
        nn.Conv2d(channel_num, channel_num, 3, int(stride/stride), padding=1),
        nn.BatchNorm2d(channel_num),
    )
    self.relu = nn.ReLU() #Definiramo izvan bloka zbog skip connectiona

  def forward(self, x):
    skip_connection = x
    x = self.conv1(x)
    x = self.conv2(x)
    if(skip_connection.shape != x.shape):
      skip_connection = self.downsample(skip_connection)
    x = skip_connection + x
    x = self.relu(x)
    return x

# %%
class ResidualNetwork(nn.Module):
  def __init__(self, out_channel=100, channel_num=16):
    super(ResidualNetwork, self).__init__()

    self.conv1 = nn.Sequential(
      nn.Conv2d(3, channel_num, 3, padding=1),
      nn.BatchNorm2d(channel_num),
      nn.ReLU(),
    )

    res_blocks = []

    for i in range(3 * resnet_type):
      if(i != 0 and i % resnet_type == 0):
        channel_num = channel_num*2
        res_blocks.append(ResidualBlock(channel_num, 2, nn.Sequential(
            nn.Conv2d(int(channel_num/2), channel_num, 1, 2),
            nn.BatchNorm2d(channel_num),
        )))
      else:
        res_blocks.append(ResidualBlock(channel_num, 1))

    self.residualblocks = nn.Sequential(*res_blocks)

    self.pool = nn.AdaptiveAvgPool2d((1, 1))
    self.fc = nn.Linear(64, out_channel, bias=True)

  def forward(self, x):
    x = self.conv1(x)
    x = self.residualblocks(x)
    x = self.pool(x)
    x = x.reshape(x.shape[0], -1)
    out = self.fc(x)

    return out

# %%
def runtime_evaluate(net, dataloader, iter, new=False):
    """
    Performs the runtime evaluation of the current performance of a
    given convolutional network. It can perform the evaluation on 
    both training and testing sets. Standard evaluation metrics are
    calcualted such as, accuracy and loss.
    Parameters
    ----------
    net: ConvolutionalModel
        ConvNet whose performance needs to be evaluated.
    type: bool
        True if eval is made on testing set, false otherwise
    save_path: str
        Path to the file where data should be saved.
    Return
    ------
    loss
        Current loss on the chosen set
    accuracy
        Current acc on the chosen set
    """
    net.eval()
    total = 0
    correct = 0
    lossFunc = nn.CrossEntropyLoss()
    accLoss = 0
    with torch.no_grad():
        for data in dataloader:
            images, labels = data
            if new:
              for j, elem in enumerate(labels):
                labels[j] = elem - (classes_batch_size * iter)
            images = images.to(device=device)
            labels = labels.to(device=device)

            output = net.forward(images)
            loss = lossFunc(output, labels)
            _, predictions = torch.max(output.data, 1)
            total += labels.size(0)
            accLoss += loss.item()
            correct += (predictions == labels).sum().item()

    print("Accuracy of the neural network on CIFAR_100 is: %.2f %%" %((correct/total)*100))

    return (accLoss/(total/batch_size)), (correct/total)

# %%
def plot_training_progress(save_dir, data):
  fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(16,8))

  linewidth = 2
  legend_size = 10
  train_color = 'r'
  val_color = 'g'
  
  num_points = len(data['train_loss'])
  x_data = np.linspace(1, num_points, num_points)
  ax1.set_title('Cross-entropy loss')
  ax1.plot(x_data, data['train_loss'], marker='o', color=train_color,
           linewidth=linewidth, linestyle='-', label='train')
  ax1.plot(x_data, data['valid_loss'], marker='o', color=val_color,
           linewidth=linewidth, linestyle='-', label='validation')
  ax1.legend(loc='upper right', fontsize=legend_size)
  ax2.set_title('Average class accuracy')
  ax2.plot(x_data, data['train_acc'], marker='o', color=train_color,
           linewidth=linewidth, linestyle='-', label='train')
  ax2.plot(x_data, data['valid_acc'], marker='o', color=val_color,
           linewidth=linewidth, linestyle='-', label='validation')
  ax2.legend(loc='upper left', fontsize=legend_size)
  ax3.set_title('Learning rate')
  ax3.plot(x_data, data['lr'], marker='o', color=train_color,
           linewidth=linewidth, linestyle='-', label='learning_rate')
  ax3.legend(loc='upper left', fontsize=legend_size)

  print('Plotting in: ', save_dir)
  plt.savefig(save_dir)

# %%
def final_evaluate(net, dataloader, iter, save_path, curr_classes):
    """
    Performs the final evaluation of the current performance of a
    given convolutional network. It performs evaluation on testing sets. 
    Standard evaluation metrics are calcualted such as, 
    accuracy and confusion matrix.
    Parameters
    ----------
    net: ConvolutionalModel
        ConvNet whose performance needs to be evaluated.
    save_path: str
        Path to the file where data should be saved.
    Return
    ------
    loss
        Current loss on the chosen set
    accuracy
        Current acc on the chosen set
    """
    net.eval()
    total = 0
    correct = 0
    confMatrix = np.zeros((len(curr_classes), len(curr_classes)), int)
    lossFunc = nn.CrossEntropyLoss()
    accLoss = 0
    with torch.no_grad():
        for data in dataloader:
            images, labels = data
            if len(curr_classes) == classes_batch_size:
              for j, elem in enumerate(labels):
                labels[j] = elem - (classes_batch_size * iter)
            images = images.to(device=device)
            labels = labels.to(device=device)

            output = net.forward(images)
            loss = lossFunc(output, labels)
            _, predictions = torch.max(output.data, 1)
            total += labels.size(0)
            accLoss += loss.item()
            correct += (predictions == labels).sum().item()
            for j in range(labels.size(0)):
                confMatrix[predictions[j], labels[j]] += 1

    print("Accuracy of the neural network on CIFAR_100 is: %.2f %%" %((correct/total)*100))
    with open(save_path, "a+") as f:
      f.write(str(((correct/total)*100)) + '\n')
      prec, recall = specificMetrics(confMatrix)
      np.savetxt(f, prec, fmt='%.2f')
      np.savetxt(f, recall, fmt='%.2f')

    new_conf = pd.DataFrame(confMatrix)
    new_conf.to_csv(save_path[:-3] + "csv", columns=curr_classes, index=curr_classes)
    return (accLoss/(total/batch_size)), (correct/total)

def specificMetrics(confMatrix):
    """
    Calculates precision and recall from a given confusion
    matrix and returns calculated metrics.
    Parameters
    ----------
    confMatrix: n x n numpy array
        Made from the predictions and true labels of a
        given set of data
    Return
    ------
    precc
        Precision on all classes
    recal 
        Recall on all classes
    """
    precc = np.zeros(np.size(confMatrix, 0))
    recal = np.zeros(np.size(confMatrix, 0))
    for i in range(np.size(confMatrix, 0)):
        tp = 0
        fp = 0
        fn = 0
        for j in range(np.size(confMatrix, 0)):
            if i == j:
                tp += confMatrix[i, j]
            else:
                fn += confMatrix[j, i]
                fp += confMatrix[i, j]
            
        precc[i] += tp/(tp + fp)
        recal[i] += tp/(tp + fn)

    return precc, recal

# %%
def changeTargets(targets_copy, targets, indices, classes):
  for i, elem in enumerate(targets_copy):
    targets[i] = indices.index(elem)
  new_classes = [classes[x] for x in indices]
  return new_classes

# %%
trainTransform = transforms.Compose([
    transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize((0.4915, 0.4823, 0.4468), (0.2470, 0.2435, 0.2616))])

testTransform = transforms.Compose([    
    transforms.ToTensor(),
    transforms.Normalize((0.4915, 0.4823, 0.4468), (0.2470, 0.2435, 0.2616))])


trainSet = torchvision.datasets.CIFAR100(root=os.path.join(SAVE_DIR, 'data'), train=True,
                    download=False, transform=trainTransform)
testSet = torchvision.datasets.CIFAR100(root=os.path.join(SAVE_DIR, 'data'), train=False,
                    download=False, transform=testTransform)

classes=pickle.load(open(os.path.join(SAVE_DIR, 'data/cifar-100-python/meta'), 'rb'))
classes=classes['fine_label_names']

indices = list(range(0, len(classes)))
np.random.shuffle(indices)
temp_targets = trainSet.targets.copy()
temp_testtargets = testSet.targets.copy()

classes = changeTargets(temp_targets, trainSet.targets, indices, classes)
_ = changeTargets(temp_testtargets, testSet.targets, indices, classes)
indices = list(range(0, len(classes)))
trainSet.classes = classes
testSet.classes = classes

trainLoaders = []
testLoaders = []
subsetsTrain = []
subsetsTest = []
for i in range(0, int(len(indices)/classes_batch_size)):
  indexTrain = [j for j, x in enumerate(trainSet.targets) if x in indices[classes_batch_size * i: classes_batch_size * (i + 1)]]
  indexTest = [j for j, x in enumerate(testSet.targets) if x in indices[classes_batch_size * i: classes_batch_size * (i + 1)]]
  subsetsTrain.append(torch.utils.data.Subset(trainSet, indexTrain))
  subsetsTest.append(torch.utils.data.Subset(testSet, indexTest))
  trainLoaders.append(torch.utils.data.DataLoader(subsetsTrain[i], batch_size=batch_size,
                                          shuffle=True, num_workers=0))
  testLoaders.append(torch.utils.data.DataLoader(subsetsTest[i], batch_size=batch_size,
                                          shuffle=True, num_workers=0))

# %%
def sampleExemplars(iter):
    classLabels = np.zeros(100)
    counter = 0
    indexList = []
    for i in range(len(trainSet)):
        if counter == K:
            break
        else:
            target = trainSet.targets[i]
            if target in indices[0: classes_batch_size * (iter + 1)] and classLabels[target] < int(K/(classes_batch_size * (iter + 1))):
                classLabels[target] += 1
                counter += 1
                indexList.append(i)
    exemplars = torch.utils.data.Subset(trainSet, indexList)
    exemplarsLoader = torch.utils.data.DataLoader(exemplars, batch_size=batch_size,
                                          shuffle=True, num_workers=0)
    
    return exemplarsLoader

# %%
def unpickle(file):
    with open(file, 'rb') as fo:
        dict = pickle.load(fo)
    return dict

class ImageNet32Dataset(torch.utils.data.Dataset):
    def __init__(self, file, transform=None):
        self.new = unpickle(file)
        self.transform = transform
        self.data = self.new['data']
        self.targets = [y-1 for y in self.new['labels']]

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        img, target = self.data[index], self.targets[index]

        new_img = Image.fromarray(np.array(img).reshape(3, 32, 32).T, 'RGB')

        if self.transform is not None:
            new_img = self.transform(new_img)

        return new_img, target

aux_data = ImageNet32Dataset(os.path.join(SAVE_DIR, 'ImageNet/val_data'), testTransform)

# %%
def trainNetwork(iter):
    """Performs a standard procedure for training a neural network.
    Training progress after each learning epoch is evaluated in order to
    gain insigth into ConvNets continuous performance.
    Important notes
    ---------------
    Loss function: Cross entropy loss

    Optimizer: SGD
    
    Scheduler: MultiStep
    """
    plot_data = {}
    plot_data['train_loss'] = []
    plot_data['valid_loss'] = []
    plot_data['train_acc'] = []
    plot_data['valid_acc'] = []
    plot_data['lr'] = []

    net = ResidualNetwork(classes_batch_size).to(device=device)

    lossFunc = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr=lr, weight_decay=weight_decay, momentum=momentum)
    scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[int(epoch * 0.7), int(epoch * 0.9)], gamma=gamma)    
    for e in range(epoch):
    
        accLoss = 0.0

        for i, data in enumerate(trainLoaders[iter], 0):
            inputs, labels = data
            for j, elem in enumerate(labels):
              labels[j] = elem - (classes_batch_size * iter)
            inputs = inputs.to(device=device)
            labels = labels.to(device=device)

            optimizer.zero_grad()

            outputs = net.forward(inputs)
            loss = lossFunc(outputs, labels)
            loss.backward()
            optimizer.step()

            accLoss += loss.item()

            if i % 50 == 0:
                print("Epoch: %d, Iteration: %5d, Loss: %.3f" % ((e + 1), (i), (accLoss / (i + 1))))
                
        train_loss, train_acc = runtime_evaluate(net, trainLoaders[iter], iter, True)
        val_loss, val_acc = runtime_evaluate(net, testLoaders[iter], iter, True)

        plot_data['train_loss'] += [train_loss]
        plot_data['valid_loss'] += [val_loss]
        plot_data['train_acc'] += [train_acc]
        plot_data['valid_acc'] += [val_acc]
        plot_data['lr'] += [scheduler.get_last_lr()]

        scheduler.step()
    
    plot_training_progress(os.path.join(SAVE_DIR, "plots_DMC/train_plots/training_plot_" + str(classes_batch_size) + "_" + str(iter) + ".png"), plot_data)
    return net, val_loss, val_acc

# %%
def deepModelConsolidation(net_old, net_new, out_channel, iter, trainingLoader, testingLoader):
    plot_data = {}
    plot_data['train_loss'] = []
    plot_data['valid_loss'] = []
    plot_data['train_acc'] = []
    plot_data['valid_acc'] = []
    plot_data['lr'] = []


    net = ResidualNetwork(out_channel).to(device=device)

    auxiliary_data, _ = torch.utils.data.random_split(aux_data, lengths=[18000, 32000])
    
    auxiliary_loader = torch.utils.data.DataLoader(auxiliary_data, batch_size=batch_size,
                                          shuffle=True, num_workers=0)

    consolidator = nn.MSELoss()
    optimizer = optim.SGD(net.parameters(), lr=lr_cons, weight_decay=weight_decay, momentum=momentum)
    scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[int(epoch_consolidation * 0.7), int(epoch_consolidation * 0.9)], gamma=gamma)  

    for e in range(epoch_consolidation):
    
        accLoss = 0.0

        for i, data in enumerate(auxiliary_loader, 0):
            inputs, _ = data
            inputs = inputs.to(device=device)

            optimizer.zero_grad()

            outputs = net.forward(inputs)
            outputs_old = net_old.forward(inputs)
            outputs_new = net_new.forward(inputs)
            mean_old = torch.mean(outputs_old)
            mean_new = torch.mean(outputs_new)
            for k in range(len(outputs_old)):
              outputs_old[k] = outputs_old[k] - mean_old
            for k in range(len(outputs_new)):
              outputs_new[k] = outputs_new[k] - mean_new

            outputs_goal = torch.cat((outputs_old, outputs_new), dim=1)

            loss = consolidator(outputs, outputs_goal)
            loss.backward()
            optimizer.step()

            accLoss += loss.item()

            if i % 50 == 0:
                print("Epoch: %d, Iteration: %5d, Loss: %.3f" % ((e + 1), (i), (accLoss / (i + 1))))
                
        train_loss, train_acc = runtime_evaluate(net, trainingLoader, iter)
        val_loss, val_acc = runtime_evaluate(net, testingLoader, iter)

        plot_data['train_loss'] += [train_loss]
        plot_data['valid_loss'] += [val_loss]
        plot_data['train_acc'] += [train_acc]
        plot_data['valid_acc'] += [val_acc]
        plot_data['lr'] += [scheduler.get_last_lr()]

        scheduler.step()

    plot_training_progress(os.path.join(SAVE_DIR, "plots_DMC/cons_plots/training_plot_" + str(classes_batch_size) + "_" + str(iter) + ".png"), plot_data)
      
    return net, val_loss, val_acc

# %%
def fineTuning(net, iter, trainingLoader, testingLoader):
    plot_data = {}
    plot_data['train_loss'] = []
    plot_data['valid_loss'] = []
    plot_data['train_acc'] = []
    plot_data['valid_acc'] = []
    plot_data['lr'] = []


    exemplars_loader = sampleExemplars(iter)

    consolidator = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr=lr_finetune, weight_decay=weight_decay, momentum=momentum)

    for e in range(epoch_fine_tune):
    
        accLoss = 0.0

        for i, data in enumerate(exemplars_loader, 0):
            inputs, labels = data
            inputs = inputs.to(device=device)
            labels = labels.to(device=device)

            optimizer.zero_grad()

            outputs = net.forward(inputs)
            loss = consolidator(outputs, labels)
            loss.backward()
            optimizer.step()

            accLoss += loss.item()

            if i % 10 == 0:
                print("Epoch: %d, Iteration: %5d, Loss: %.3f" % ((e + 1), (i), (accLoss / (i + 1))))
                
        train_loss, train_acc = runtime_evaluate(net, trainingLoader, iter)
        val_loss, val_acc = runtime_evaluate(net, testingLoader, iter)

        plot_data['train_loss'] += [train_loss]
        plot_data['valid_loss'] += [val_loss]
        plot_data['train_acc'] += [train_acc]
        plot_data['valid_acc'] += [val_acc]
        plot_data['lr'] += [lr_finetune]

    val_loss, val_acc = final_evaluate(net, testingLoader, iter, os.path.join(SAVE_DIR, "fine_tune_eval/final_eval_"+ str(K) + "_" + str(classes_batch_size) + "/fine_" + str(iter) + ".txt"), classes[0:(iter + 1)*classes_batch_size])
    plot_training_progress(os.path.join(SAVE_DIR, "plots_DMC/fine_tune_plots/training_plot_" + str(classes_batch_size) + "_" + str(iter) + ".png"), plot_data)
      
    return net, val_loss, val_acc

# %%
if __name__=='__main__':
  plot_data = {}
  plot_data['batch_loss'] = []
  plot_data['batch_acc'] = []
  plot_data['iter'] = [0]
  plot_data['batch_train_loss'] = []
  plot_data['batch_train_acc'] = []
  plot_data['batch_dmc_loss'] = []
  plot_data['batch_dmc_acc'] = []
  print("Train a new network:")
  print("=================")
  print(classes[0:classes_batch_size])
  print("=================")
  network, val_loss, val_acc = trainNetwork(0)
  plot_data['batch_loss'].append(val_loss)
  plot_data['batch_acc'].append(val_acc)
  print("=================")
  print("ITERATION:", 0, "\nAccuracy:", val_acc, "\nLoss:", val_loss)
  for iter in range(1, int(len(classes)/classes_batch_size)):
    eval_traindataset = torch.utils.data.ConcatDataset(subsetsTrain[0:iter])
    eval_testdataset = torch.utils.data.ConcatDataset(subsetsTest[0:iter])
    eval_trainloader = torch.utils.data.DataLoader(eval_traindataset, batch_size=batch_size,
                                          shuffle=True, num_workers=0)
    eval_testloader = torch.utils.data.DataLoader(eval_testdataset, batch_size=batch_size,
                                      shuffle=True, num_workers=0)
    print("Train a new network:")
    print("=================")
    print(classes[classes_batch_size * (iter):classes_batch_size * (iter+1)])
    print("=================")
    newNetwork, val_loss, val_acc = trainNetwork(iter)
    plot_data['batch_train_loss'].append(val_loss)
    plot_data['batch_train_acc'].append(val_acc)
    print("Consolidation stage:")
    print("=================")
    consolidateNetwork, val_loss, val_acc = deepModelConsolidation(network, newNetwork, classes_batch_size * (iter+1), iter, eval_trainloader, eval_testloader)
    plot_data['batch_dmc_loss'].append(val_loss)
    plot_data['batch_dmc_acc'].append(val_acc)
    print("Fine tuning stage:")
    print("=================")
    network, val_loss, val_acc = fineTuning(consolidateNetwork, iter, eval_trainloader, eval_testloader)
    plot_data['batch_loss'].append(val_loss)
    plot_data['batch_acc'].append(val_acc)
    plot_data['iter'].append(iter)
    print("=================")
    print("ITERATION:", iter, "\nAccuracy:", val_acc, "\nLoss:", val_loss)

  with open(os.path.join(SAVE_DIR, "final_eval_data/eval_" + str(K) + "_" + str(classes_batch_size) + ".txt"), 'a+') as f:
    f.write("Train accuracy\n")
    f.write(str(plot_data['batch_train_acc']) + "\n")
    f.write("Train loss\n")
    f.write(str(plot_data['batch_train_loss']) + "\n")
    f.write("Consolidation accuracy\n")
    f.write(str(plot_data['batch_dmc_acc']) + "\n")
    f.write("Consolidation loss\n")
    f.write(str(plot_data['batch_dmc_loss']) + "\n")
    f.write("Final accuracy\n")
    f.write(str(plot_data['batch_acc']) + "\n")
    f.write("Final loss\n")
    f.write(str(plot_data['batch_loss']) + "\n")
    f.write(str(plot_data['iter']))

  PATH = os.path.join(SAVE_DIR, "CIFAR_100/dmc_net_" + str(K) + ".pth")
  torch.save(net.state_dict(), PATH)
# Out:
# Train a new network:
# =================
# ['bed', 'raccoon', 'plain', 'pine_tree', 'oak_tree']
# =================
# Epoch: 1, Iteration:     0, Loss: 2.018
# Accuracy of the neural network on CIFAR_100 is: 24.28 %
# Accuracy of the neural network on CIFAR_100 is: 25.20 %
# Epoch: 2, Iteration:     0, Loss: 1.591
# Accuracy of the neural network on CIFAR_100 is: 20.00 %
# Accuracy of the neural network on CIFAR_100 is: 20.00 %
# Epoch: 3, Iteration:     0, Loss: 1.635
# Accuracy of the neural network on CIFAR_100 is: 20.00 %
# Accuracy of the neural network on CIFAR_100 is: 20.00 %
# Epoch: 4, Iteration:     0, Loss: 1.610
# Accuracy of the neural network on CIFAR_100 is: 20.00 %
# Accuracy of the neural network on CIFAR_100 is: 20.00 %
# Epoch: 5, Iteration:     0, Loss: 1.616
# Accuracy of the neural network on CIFAR_100 is: 20.00 %
# Accuracy of the neural network on CIFAR_100 is: 20.00 %
# Epoch: 6, Iteration:     0, Loss: 1.612
# Accuracy of the neural network on CIFAR_100 is: 20.00 %
# Accuracy of the neural network on CIFAR_100 is: 20.00 %
# Epoch: 7, Iteration:     0, Loss: 1.609
# Accuracy of the neural network on CIFAR_100 is: 20.00 %
# Accuracy of the neural network on CIFAR_100 is: 20.00 %
# Epoch: 8, Iteration:     0, Loss: 1.611
# Accuracy of the neural network on CIFAR_100 is: 20.00 %
# Accuracy of the neural network on CIFAR_100 is: 20.00 %
# Epoch: 9, Iteration:     0, Loss: 1.609
# Accuracy of the neural network on CIFAR_100 is: 20.00 %
# Accuracy of the neural network on CIFAR_100 is: 20.00 %
# Epoch: 10, Iteration:     0, Loss: 1.612
# Accuracy of the neural network on CIFAR_100 is: 20.00 %
# Accuracy of the neural network on CIFAR_100 is: 20.00 %
# Epoch: 11, Iteration:     0, Loss: 1.609
# Accuracy of the neural network on CIFAR_100 is: 20.24 %
# Accuracy of the neural network on CIFAR_100 is: 20.20 %
# Epoch: 12, Iteration:     0, Loss: 1.610
# Accuracy of the neural network on CIFAR_100 is: 21.32 %
# Accuracy of the neural network on CIFAR_100 is: 27.40 %
# Epoch: 13, Iteration:     0, Loss: 1.608
# Accuracy of the neural network on CIFAR_100 is: 20.00 %
# Accuracy of the neural network on CIFAR_100 is: 20.00 %
# Epoch: 14, Iteration:     0, Loss: 1.607
# Accuracy of the neural network on CIFAR_100 is: 20.32 %
# Accuracy of the neural network on CIFAR_100 is: 21.80 %
# Epoch: 15, Iteration:     0, Loss: 1.605
# Accuracy of the neural network on CIFAR_100 is: 22.48 %
# Accuracy of the neural network on CIFAR_100 is: 30.40 %
# Epoch: 16, Iteration:     0, Loss: 1.602
# Accuracy of the neural network on CIFAR_100 is: 31.28 %
# Accuracy of the neural network on CIFAR_100 is: 41.00 %
# Epoch: 17, Iteration:     0, Loss: 1.555
# Accuracy of the neural network on CIFAR_100 is: 25.68 %
# Accuracy of the neural network on CIFAR_100 is: 25.80 %
# Epoch: 18, Iteration:     0, Loss: 1.580
# Accuracy of the neural network on CIFAR_100 is: 30.52 %
# Accuracy of the neural network on CIFAR_100 is: 44.60 %
# Epoch: 19, Iteration:     0, Loss: 1.614
# Accuracy of the neural network on CIFAR_100 is: 33.44 %
# Accuracy of the neural network on CIFAR_100 is: 36.80 %
# Epoch: 20, Iteration:     0, Loss: 1.454
# Accuracy of the neural network on CIFAR_100 is: 35.28 %
# Accuracy of the neural network on CIFAR_100 is: 38.20 %
# Epoch: 21, Iteration:     0, Loss: 1.525
# Accuracy of the neural network on CIFAR_100 is: 33.44 %
# Accuracy of the neural network on CIFAR_100 is: 42.00 %
# Epoch: 22, Iteration:     0, Loss: 1.506
# Accuracy of the neural network on CIFAR_100 is: 39.60 %
# Accuracy of the neural network on CIFAR_100 is: 46.40 %
# Epoch: 23, Iteration:     0, Loss: 1.461
# Accuracy of the neural network on CIFAR_100 is: 45.96 %
# Accuracy of the neural network on CIFAR_100 is: 53.20 %
# Epoch: 24, Iteration:     0, Loss: 1.189
# Accuracy of the neural network on CIFAR_100 is: 49.20 %
# Accuracy of the neural network on CIFAR_100 is: 58.20 %
# Epoch: 25, Iteration:     0, Loss: 1.169
# Accuracy of the neural network on CIFAR_100 is: 56.60 %
# Accuracy of the neural network on CIFAR_100 is: 62.60 %
# Epoch: 26, Iteration:     0, Loss: 1.097
# Accuracy of the neural network on CIFAR_100 is: 44.32 %
# Accuracy of the neural network on CIFAR_100 is: 47.80 %
# Epoch: 27, Iteration:     0, Loss: 1.277
# Accuracy of the neural network on CIFAR_100 is: 59.88 %
# Accuracy of the neural network on CIFAR_100 is: 64.20 %
# Epoch: 28, Iteration:     0, Loss: 0.980
# Accuracy of the neural network on CIFAR_100 is: 61.52 %
# Accuracy of the neural network on CIFAR_100 is: 64.60 %
# Epoch: 29, Iteration:     0, Loss: 0.945
# Accuracy of the neural network on CIFAR_100 is: 65.20 %
# Accuracy of the neural network on CIFAR_100 is: 69.40 %
# Epoch: 30, Iteration:     0, Loss: 0.820
# Accuracy of the neural network on CIFAR_100 is: 69.72 %
# Accuracy of the neural network on CIFAR_100 is: 74.40 %
# Epoch: 31, Iteration:     0, Loss: 0.748
# Accuracy of the neural network on CIFAR_100 is: 67.44 %
# Accuracy of the neural network on CIFAR_100 is: 69.20 %
# Epoch: 32, Iteration:     0, Loss: 0.770
# Accuracy of the neural network on CIFAR_100 is: 66.92 %
# Accuracy of the neural network on CIFAR_100 is: 67.80 %
# Epoch: 33, Iteration:     0, Loss: 0.742
# Accuracy of the neural network on CIFAR_100 is: 69.28 %
# Accuracy of the neural network on CIFAR_100 is: 75.60 %
# Epoch: 34, Iteration:     0, Loss: 0.674
# Accuracy of the neural network on CIFAR_100 is: 67.36 %
# Accuracy of the neural network on CIFAR_100 is: 71.80 %
# Epoch: 35, Iteration:     0, Loss: 0.730
# Accuracy of the neural network on CIFAR_100 is: 71.16 %
# Accuracy of the neural network on CIFAR_100 is: 70.60 %
# Epoch: 36, Iteration:     0, Loss: 0.668
# Accuracy of the neural network on CIFAR_100 is: 72.92 %
# Accuracy of the neural network on CIFAR_100 is: 72.40 %
# Epoch: 37, Iteration:     0, Loss: 0.741
# Accuracy of the neural network on CIFAR_100 is: 73.76 %
# Accuracy of the neural network on CIFAR_100 is: 76.00 %
# Epoch: 38, Iteration:     0, Loss: 0.678
# Accuracy of the neural network on CIFAR_100 is: 72.96 %
# Accuracy of the neural network on CIFAR_100 is: 73.60 %
# Epoch: 39, Iteration:     0, Loss: 0.478
# Accuracy of the neural network on CIFAR_100 is: 69.96 %
# Accuracy of the neural network on CIFAR_100 is: 70.60 %
# Epoch: 40, Iteration:     0, Loss: 0.753
# Accuracy of the neural network on CIFAR_100 is: 74.28 %
# Accuracy of the neural network on CIFAR_100 is: 75.00 %
# Epoch: 41, Iteration:     0, Loss: 0.675
# Accuracy of the neural network on CIFAR_100 is: 76.84 %
# Accuracy of the neural network on CIFAR_100 is: 78.00 %
# Epoch: 42, Iteration:     0, Loss: 0.491
# Accuracy of the neural network on CIFAR_100 is: 78.08 %
# Accuracy of the neural network on CIFAR_100 is: 77.20 %
# Epoch: 43, Iteration:     0, Loss: 0.699
# Accuracy of the neural network on CIFAR_100 is: 75.72 %
# Accuracy of the neural network on CIFAR_100 is: 74.60 %
# Epoch: 44, Iteration:     0, Loss: 0.651
# Accuracy of the neural network on CIFAR_100 is: 79.84 %
# Accuracy of the neural network on CIFAR_100 is: 78.40 %
# Epoch: 45, Iteration:     0, Loss: 0.485
# Accuracy of the neural network on CIFAR_100 is: 78.08 %
# Accuracy of the neural network on CIFAR_100 is: 77.00 %
# Epoch: 46, Iteration:     0, Loss: 0.695
# Accuracy of the neural network on CIFAR_100 is: 78.24 %
# Accuracy of the neural network on CIFAR_100 is: 78.40 %
# Epoch: 47, Iteration:     0, Loss: 0.585
# Accuracy of the neural network on CIFAR_100 is: 77.24 %
# Accuracy of the neural network on CIFAR_100 is: 78.00 %
# Epoch: 48, Iteration:     0, Loss: 0.653
# Accuracy of the neural network on CIFAR_100 is: 78.68 %
# Accuracy of the neural network on CIFAR_100 is: 77.80 %
# Epoch: 49, Iteration:     0, Loss: 0.594
# Accuracy of the neural network on CIFAR_100 is: 76.04 %
# Accuracy of the neural network on CIFAR_100 is: 77.00 %
# Epoch: 50, Iteration:     0, Loss: 0.506
# Accuracy of the neural network on CIFAR_100 is: 80.04 %
# Accuracy of the neural network on CIFAR_100 is: 80.00 %
# Epoch: 51, Iteration:     0, Loss: 0.610
# Accuracy of the neural network on CIFAR_100 is: 79.36 %
# Accuracy of the neural network on CIFAR_100 is: 78.80 %
# Epoch: 52, Iteration:     0, Loss: 0.627
# Accuracy of the neural network on CIFAR_100 is: 81.48 %
# Accuracy of the neural network on CIFAR_100 is: 78.40 %
# Epoch: 53, Iteration:     0, Loss: 0.527
# Accuracy of the neural network on CIFAR_100 is: 76.80 %
# Accuracy of the neural network on CIFAR_100 is: 74.00 %
# Epoch: 54, Iteration:     0, Loss: 0.601
# Accuracy of the neural network on CIFAR_100 is: 77.40 %
# Accuracy of the neural network on CIFAR_100 is: 76.00 %
# Epoch: 55, Iteration:     0, Loss: 0.533
# Accuracy of the neural network on CIFAR_100 is: 79.64 %
# Accuracy of the neural network on CIFAR_100 is: 79.20 %
# Epoch: 56, Iteration:     0, Loss: 0.535
# Accuracy of the neural network on CIFAR_100 is: 80.80 %
# Accuracy of the neural network on CIFAR_100 is: 78.20 %
# Epoch: 57, Iteration:     0, Loss: 0.457
# Accuracy of the neural network on CIFAR_100 is: 81.60 %
# Accuracy of the neural network on CIFAR_100 is: 80.60 %
# Epoch: 58, Iteration:     0, Loss: 0.414
# Accuracy of the neural network on CIFAR_100 is: 81.20 %
# Accuracy of the neural network on CIFAR_100 is: 79.00 %
# Epoch: 59, Iteration:     0, Loss: 0.415
# Accuracy of the neural network on CIFAR_100 is: 80.16 %
# Accuracy of the neural network on CIFAR_100 is: 79.60 %
# Epoch: 60, Iteration:     0, Loss: 0.487
# Accuracy of the neural network on CIFAR_100 is: 82.12 %
# Accuracy of the neural network on CIFAR_100 is: 80.60 %
# Epoch: 61, Iteration:     0, Loss: 0.488
# Accuracy of the neural network on CIFAR_100 is: 79.08 %
# Accuracy of the neural network on CIFAR_100 is: 78.80 %
# Epoch: 62, Iteration:     0, Loss: 0.444
# Accuracy of the neural network on CIFAR_100 is: 83.08 %
# Accuracy of the neural network on CIFAR_100 is: 79.80 %
# Epoch: 63, Iteration:     0, Loss: 0.273
# Accuracy of the neural network on CIFAR_100 is: 77.96 %
# Accuracy of the neural network on CIFAR_100 is: 78.20 %
# Epoch: 64, Iteration:     0, Loss: 0.405
# Accuracy of the neural network on CIFAR_100 is: 79.96 %
# Accuracy of the neural network on CIFAR_100 is: 77.60 %
# Epoch: 65, Iteration:     0, Loss: 0.627
# Accuracy of the neural network on CIFAR_100 is: 81.56 %
# Accuracy of the neural network on CIFAR_100 is: 82.80 %
# Epoch: 66, Iteration:     0, Loss: 0.484
# Accuracy of the neural network on CIFAR_100 is: 83.24 %
# Accuracy of the neural network on CIFAR_100 is: 80.80 %
# Epoch: 67, Iteration:     0, Loss: 0.463
# Accuracy of the neural network on CIFAR_100 is: 81.84 %
# Accuracy of the neural network on CIFAR_100 is: 82.60 %
# Epoch: 68, Iteration:     0, Loss: 0.507
# Accuracy of the neural network on CIFAR_100 is: 83.68 %
# Accuracy of the neural network on CIFAR_100 is: 82.40 %
# Epoch: 69, Iteration:     0, Loss: 0.350
# Accuracy of the neural network on CIFAR_100 is: 83.44 %
# Accuracy of the neural network on CIFAR_100 is: 81.20 %
# Epoch: 70, Iteration:     0, Loss: 0.295
# Accuracy of the neural network on CIFAR_100 is: 83.32 %
# Accuracy of the neural network on CIFAR_100 is: 82.00 %
# Epoch: 71, Iteration:     0, Loss: 0.529
# Accuracy of the neural network on CIFAR_100 is: 86.16 %
# Accuracy of the neural network on CIFAR_100 is: 84.40 %
# Epoch: 72, Iteration:     0, Loss: 0.318
# Accuracy of the neural network on CIFAR_100 is: 87.20 %
# Accuracy of the neural network on CIFAR_100 is: 83.60 %
# Epoch: 73, Iteration:     0, Loss: 0.367
# Accuracy of the neural network on CIFAR_100 is: 86.52 %
# Accuracy of the neural network on CIFAR_100 is: 83.40 %
# Epoch: 74, Iteration:     0, Loss: 0.421
# Accuracy of the neural network on CIFAR_100 is: 86.36 %
# Accuracy of the neural network on CIFAR_100 is: 84.00 %
# Epoch: 75, Iteration:     0, Loss: 0.291
# Accuracy of the neural network on CIFAR_100 is: 86.92 %
# Accuracy of the neural network on CIFAR_100 is: 83.40 %
# Epoch: 76, Iteration:     0, Loss: 0.350
# Accuracy of the neural network on CIFAR_100 is: 87.16 %
# Accuracy of the neural network on CIFAR_100 is: 83.80 %
# Epoch: 77, Iteration:     0, Loss: 0.494
# Accuracy of the neural network on CIFAR_100 is: 87.68 %
# Accuracy of the neural network on CIFAR_100 is: 85.00 %
# Epoch: 78, Iteration:     0, Loss: 0.384
# Accuracy of the neural network on CIFAR_100 is: 87.48 %
# Accuracy of the neural network on CIFAR_100 is: 85.20 %
# Epoch: 79, Iteration:     0, Loss: 0.295
# Accuracy of the neural network on CIFAR_100 is: 86.76 %
# Accuracy of the neural network on CIFAR_100 is: 84.40 %
# Epoch: 80, Iteration:     0, Loss: 0.410
# Accuracy of the neural network on CIFAR_100 is: 87.16 %
# Accuracy of the neural network on CIFAR_100 is: 85.40 %
# Epoch: 81, Iteration:     0, Loss: 0.321
# Accuracy of the neural network on CIFAR_100 is: 87.72 %
# Accuracy of the neural network on CIFAR_100 is: 84.40 %
# Epoch: 82, Iteration:     0, Loss: 0.325
# Accuracy of the neural network on CIFAR_100 is: 88.12 %
# Accuracy of the neural network on CIFAR_100 is: 84.80 %
# Epoch: 83, Iteration:     0, Loss: 0.298
# Accuracy of the neural network on CIFAR_100 is: 88.04 %
# Accuracy of the neural network on CIFAR_100 is: 84.60 %
# Epoch: 84, Iteration:     0, Loss: 0.397
# Accuracy of the neural network on CIFAR_100 is: 87.04 %
# Accuracy of the neural network on CIFAR_100 is: 84.40 %
# Epoch: 85, Iteration:     0, Loss: 0.269
# Accuracy of the neural network on CIFAR_100 is: 87.40 %
# Accuracy of the neural network on CIFAR_100 is: 85.60 %
# Epoch: 86, Iteration:     0, Loss: 0.353
# Accuracy of the neural network on CIFAR_100 is: 88.12 %
# Accuracy of the neural network on CIFAR_100 is: 85.40 %
# Epoch: 87, Iteration:     0, Loss: 0.337
# Accuracy of the neural network on CIFAR_100 is: 88.04 %
# Accuracy of the neural network on CIFAR_100 is: 84.00 %
# Epoch: 88, Iteration:     0, Loss: 0.290
# Accuracy of the neural network on CIFAR_100 is: 87.60 %
# Accuracy of the neural network on CIFAR_100 is: 84.20 %
# Epoch: 89, Iteration:     0, Loss: 0.343
# Accuracy of the neural network on CIFAR_100 is: 87.72 %
# Accuracy of the neural network on CIFAR_100 is: 85.00 %
# Epoch: 90, Iteration:     0, Loss: 0.384
# Accuracy of the neural network on CIFAR_100 is: 87.28 %
# Accuracy of the neural network on CIFAR_100 is: 85.20 %
# Epoch: 91, Iteration:     0, Loss: 0.267
# Accuracy of the neural network on CIFAR_100 is: 87.92 %
# Accuracy of the neural network on CIFAR_100 is: 85.40 %
# Epoch: 92, Iteration:     0, Loss: 0.345
# Accuracy of the neural network on CIFAR_100 is: 87.92 %
# Accuracy of the neural network on CIFAR_100 is: 85.40 %
# Epoch: 93, Iteration:     0, Loss: 0.226
# Accuracy of the neural network on CIFAR_100 is: 87.64 %
# Accuracy of the neural network on CIFAR_100 is: 85.20 %
# Epoch: 94, Iteration:     0, Loss: 0.434
# Accuracy of the neural network on CIFAR_100 is: 86.92 %
# Accuracy of the neural network on CIFAR_100 is: 85.40 %
# Epoch: 95, Iteration:     0, Loss: 0.247
# Accuracy of the neural network on CIFAR_100 is: 88.32 %
# Accuracy of the neural network on CIFAR_100 is: 85.40 %
# Epoch: 96, Iteration:     0, Loss: 0.262
# Accuracy of the neural network on CIFAR_100 is: 88.00 %
# Accuracy of the neural network on CIFAR_100 is: 85.00 %
# Epoch: 97, Iteration:     0, Loss: 0.341
# Accuracy of the neural network on CIFAR_100 is: 88.12 %
# Accuracy of the neural network on CIFAR_100 is: 85.60 %
# Epoch: 98, Iteration:     0, Loss: 0.330
# Accuracy of the neural network on CIFAR_100 is: 88.20 %
# Accuracy of the neural network on CIFAR_100 is: 85.80 %
# Epoch: 99, Iteration:     0, Loss: 0.207
# Accuracy of the neural network on CIFAR_100 is: 87.56 %
# Accuracy of the neural network on CIFAR_100 is: 85.20 %
# Epoch: 100, Iteration:     0, Loss: 0.281
# Accuracy of the neural network on CIFAR_100 is: 88.44 %
# Accuracy of the neural network on CIFAR_100 is: 85.20 %
# Plotting in:  /content/drive/MyDrive/Zavrsni/plots_DMC/train_plots/training_plot_5_0.png
# =================
# ITERATION: 0
# Accuracy: 0.852
# Loss: 0.4016362075805664
# Train a new network:
# =================
# ['dinosaur', 'spider', 'plate', 'cup', 'woman']
# =================
# Epoch: 1, Iteration:     0, Loss: 1.957
# Accuracy of the neural network on CIFAR_100 is: 23.92 %
# Accuracy of the neural network on CIFAR_100 is: 24.40 %
# Epoch: 2, Iteration:     0, Loss: 1.584
# Accuracy of the neural network on CIFAR_100 is: 26.44 %
# Accuracy of the neural network on CIFAR_100 is: 25.40 %
# Epoch: 3, Iteration:     0, Loss: 1.555
# Accuracy of the neural network on CIFAR_100 is: 32.04 %
# Accuracy of the neural network on CIFAR_100 is: 32.80 %
# Epoch: 4, Iteration:     0, Loss: 1.533
# Accuracy of the neural network on CIFAR_100 is: 26.68 %
# Accuracy of the neural network on CIFAR_100 is: 27.80 %
# Epoch: 5, Iteration:     0, Loss: 1.599
# Accuracy of the neural network on CIFAR_100 is: 27.76 %
# Accuracy of the neural network on CIFAR_100 is: 25.80 %
# Epoch: 6, Iteration:     0, Loss: 1.555
# Accuracy of the neural network on CIFAR_100 is: 34.52 %
# Accuracy of the neural network on CIFAR_100 is: 36.80 %
# Epoch: 7, Iteration:     0, Loss: 1.536
# Accuracy of the neural network on CIFAR_100 is: 35.80 %
# Accuracy of the neural network on CIFAR_100 is: 39.40 %
# Epoch: 8, Iteration:     0, Loss: 1.504
# Accuracy of the neural network on CIFAR_100 is: 38.60 %
# Accuracy of the neural network on CIFAR_100 is: 38.80 %
# Epoch: 9, Iteration:     0, Loss: 1.462
# Accuracy of the neural network on CIFAR_100 is: 35.16 %
# Accuracy of the neural network on CIFAR_100 is: 39.00 %
# Epoch: 10, Iteration:     0, Loss: 1.436
# Accuracy of the neural network on CIFAR_100 is: 39.40 %
# Accuracy of the neural network on CIFAR_100 is: 42.20 %
# Epoch: 11, Iteration:     0, Loss: 1.400
# Accuracy of the neural network on CIFAR_100 is: 45.36 %
# Accuracy of the neural network on CIFAR_100 is: 49.40 %
# Epoch: 12, Iteration:     0, Loss: 1.267
# Accuracy of the neural network on CIFAR_100 is: 46.16 %
# Accuracy of the neural network on CIFAR_100 is: 49.60 %
# Epoch: 13, Iteration:     0, Loss: 1.395
# Accuracy of the neural network on CIFAR_100 is: 39.80 %
# Accuracy of the neural network on CIFAR_100 is: 46.20 %
# Epoch: 14, Iteration:     0, Loss: 1.423
# Accuracy of the neural network on CIFAR_100 is: 47.04 %
# Accuracy of the neural network on CIFAR_100 is: 51.80 %
# Epoch: 15, Iteration:     0, Loss: 1.313
# Accuracy of the neural network on CIFAR_100 is: 47.44 %
# Accuracy of the neural network on CIFAR_100 is: 47.00 %
# Epoch: 16, Iteration:     0, Loss: 1.353
# Accuracy of the neural network on CIFAR_100 is: 46.76 %
# Accuracy of the neural network on CIFAR_100 is: 52.60 %
# Epoch: 17, Iteration:     0, Loss: 1.194
# Accuracy of the neural network on CIFAR_100 is: 48.76 %
# Accuracy of the neural network on CIFAR_100 is: 53.00 %
# Epoch: 18, Iteration:     0, Loss: 1.178
# Accuracy of the neural network on CIFAR_100 is: 56.72 %
# Accuracy of the neural network on CIFAR_100 is: 58.20 %
# Epoch: 19, Iteration:     0, Loss: 1.123
# Accuracy of the neural network on CIFAR_100 is: 54.08 %
# Accuracy of the neural network on CIFAR_100 is: 62.00 %
# Epoch: 20, Iteration:     0, Loss: 1.204
# Accuracy of the neural network on CIFAR_100 is: 58.16 %
# Accuracy of the neural network on CIFAR_100 is: 62.60 %
# Epoch: 21, Iteration:     0, Loss: 1.123
# Accuracy of the neural network on CIFAR_100 is: 54.64 %
# Accuracy of the neural network on CIFAR_100 is: 59.40 %
# Epoch: 22, Iteration:     0, Loss: 1.087
# Accuracy of the neural network on CIFAR_100 is: 54.60 %
# Accuracy of the neural network on CIFAR_100 is: 59.00 %
# Epoch: 23, Iteration:     0, Loss: 1.057
# Accuracy of the neural network on CIFAR_100 is: 60.52 %
# Accuracy of the neural network on CIFAR_100 is: 64.20 %
# Epoch: 24, Iteration:     0, Loss: 0.826
# Accuracy of the neural network on CIFAR_100 is: 60.20 %
# Accuracy of the neural network on CIFAR_100 is: 66.60 %
# Epoch: 25, Iteration:     0, Loss: 0.933
# Accuracy of the neural network on CIFAR_100 is: 63.76 %
# Accuracy of the neural network on CIFAR_100 is: 68.40 %
# Epoch: 26, Iteration:     0, Loss: 1.024
# Accuracy of the neural network on CIFAR_100 is: 66.00 %
# Accuracy of the neural network on CIFAR_100 is: 69.80 %
# Epoch: 27, Iteration:     0, Loss: 0.791
# Accuracy of the neural network on CIFAR_100 is: 63.24 %
# Accuracy of the neural network on CIFAR_100 is: 68.20 %
# Epoch: 28, Iteration:     0, Loss: 0.839
# Accuracy of the neural network on CIFAR_100 is: 66.96 %
# Accuracy of the neural network on CIFAR_100 is: 69.00 %
# Epoch: 29, Iteration:     0, Loss: 1.013
# Accuracy of the neural network on CIFAR_100 is: 71.20 %
# Accuracy of the neural network on CIFAR_100 is: 72.00 %
# Epoch: 30, Iteration:     0, Loss: 0.808
# Accuracy of the neural network on CIFAR_100 is: 72.08 %
# Accuracy of the neural network on CIFAR_100 is: 72.80 %
# Epoch: 31, Iteration:     0, Loss: 0.771
# Accuracy of the neural network on CIFAR_100 is: 72.00 %
# Accuracy of the neural network on CIFAR_100 is: 71.60 %
# Epoch: 32, Iteration:     0, Loss: 0.595
# Accuracy of the neural network on CIFAR_100 is: 72.08 %
# Accuracy of the neural network on CIFAR_100 is: 76.60 %
# Epoch: 33, Iteration:     0, Loss: 0.775
# Accuracy of the neural network on CIFAR_100 is: 71.00 %
# Accuracy of the neural network on CIFAR_100 is: 70.00 %
# Epoch: 34, Iteration:     0, Loss: 0.776
# Accuracy of the neural network on CIFAR_100 is: 77.84 %
# Accuracy of the neural network on CIFAR_100 is: 76.20 %
# Epoch: 35, Iteration:     0, Loss: 0.568
# Accuracy of the neural network on CIFAR_100 is: 77.24 %
# Accuracy of the neural network on CIFAR_100 is: 76.20 %
# Epoch: 36, Iteration:     0, Loss: 0.569
# Accuracy of the neural network on CIFAR_100 is: 76.32 %
# Accuracy of the neural network on CIFAR_100 is: 78.00 %
# Epoch: 37, Iteration:     0, Loss: 0.635
# Accuracy of the neural network on CIFAR_100 is: 74.72 %
# Accuracy of the neural network on CIFAR_100 is: 76.40 %
# Epoch: 38, Iteration:     0, Loss: 0.673
# Accuracy of the neural network on CIFAR_100 is: 76.24 %
# Accuracy of the neural network on CIFAR_100 is: 77.20 %
# Epoch: 39, Iteration:     0, Loss: 0.651
# Accuracy of the neural network on CIFAR_100 is: 79.48 %
# Accuracy of the neural network on CIFAR_100 is: 80.00 %
# Epoch: 40, Iteration:     0, Loss: 0.518
# Accuracy of the neural network on CIFAR_100 is: 78.76 %
# Accuracy of the neural network on CIFAR_100 is: 77.80 %
# Epoch: 41, Iteration:     0, Loss: 0.590
# Accuracy of the neural network on CIFAR_100 is: 80.08 %
# Accuracy of the neural network on CIFAR_100 is: 78.20 %
# Epoch: 42, Iteration:     0, Loss: 0.540
# Accuracy of the neural network on CIFAR_100 is: 80.40 %
# Accuracy of the neural network on CIFAR_100 is: 80.20 %
# Epoch: 43, Iteration:     0, Loss: 0.399
# Accuracy of the neural network on CIFAR_100 is: 80.80 %
# Accuracy of the neural network on CIFAR_100 is: 81.20 %
# Epoch: 44, Iteration:     0, Loss: 0.451
# Accuracy of the neural network on CIFAR_100 is: 79.72 %
# Accuracy of the neural network on CIFAR_100 is: 78.00 %
# Epoch: 45, Iteration:     0, Loss: 0.591
# Accuracy of the neural network on CIFAR_100 is: 82.56 %
# Accuracy of the neural network on CIFAR_100 is: 82.60 %
# Epoch: 46, Iteration:     0, Loss: 0.364
# Accuracy of the neural network on CIFAR_100 is: 80.04 %
# Accuracy of the neural network on CIFAR_100 is: 81.00 %
# Epoch: 47, Iteration:     0, Loss: 0.568
# Accuracy of the neural network on CIFAR_100 is: 80.60 %
# Accuracy of the neural network on CIFAR_100 is: 80.20 %
# Epoch: 48, Iteration:     0, Loss: 0.458
# Accuracy of the neural network on CIFAR_100 is: 83.36 %
# Accuracy of the neural network on CIFAR_100 is: 83.60 %
# Epoch: 49, Iteration:     0, Loss: 0.466
# Accuracy of the neural network on CIFAR_100 is: 82.72 %
# Accuracy of the neural network on CIFAR_100 is: 82.80 %
# Epoch: 50, Iteration:     0, Loss: 0.346
# Accuracy of the neural network on CIFAR_100 is: 82.96 %
# Accuracy of the neural network on CIFAR_100 is: 81.80 %
# Epoch: 51, Iteration:     0, Loss: 0.439
# Accuracy of the neural network on CIFAR_100 is: 83.28 %
# Accuracy of the neural network on CIFAR_100 is: 83.00 %
# Epoch: 52, Iteration:     0, Loss: 0.317
# Accuracy of the neural network on CIFAR_100 is: 83.20 %
# Accuracy of the neural network on CIFAR_100 is: 80.80 %
# Epoch: 53, Iteration:     0, Loss: 0.438
# Accuracy of the neural network on CIFAR_100 is: 86.28 %
# Accuracy of the neural network on CIFAR_100 is: 80.20 %
# Epoch: 54, Iteration:     0, Loss: 0.369
# Accuracy of the neural network on CIFAR_100 is: 85.88 %
# Accuracy of the neural network on CIFAR_100 is: 81.40 %
# Epoch: 55, Iteration:     0, Loss: 0.379
# Accuracy of the neural network on CIFAR_100 is: 84.20 %
# Accuracy of the neural network on CIFAR_100 is: 83.40 %
# Epoch: 56, Iteration:     0, Loss: 0.356
# Accuracy of the neural network on CIFAR_100 is: 84.04 %
# Accuracy of the neural network on CIFAR_100 is: 81.40 %
# Epoch: 57, Iteration:     0, Loss: 0.423
# Accuracy of the neural network on CIFAR_100 is: 86.44 %
# Accuracy of the neural network on CIFAR_100 is: 83.00 %
# Epoch: 58, Iteration:     0, Loss: 0.420
# Accuracy of the neural network on CIFAR_100 is: 84.08 %
# Accuracy of the neural network on CIFAR_100 is: 80.60 %
# Epoch: 59, Iteration:     0, Loss: 0.432
# Accuracy of the neural network on CIFAR_100 is: 87.44 %
# Accuracy of the neural network on CIFAR_100 is: 80.20 %
# Epoch: 60, Iteration:     0, Loss: 0.421
# Accuracy of the neural network on CIFAR_100 is: 82.84 %
# Accuracy of the neural network on CIFAR_100 is: 79.20 %
# Epoch: 61, Iteration:     0, Loss: 0.487
# Accuracy of the neural network on CIFAR_100 is: 88.72 %
# Accuracy of the neural network on CIFAR_100 is: 83.00 %
# Epoch: 62, Iteration:     0, Loss: 0.267
# Accuracy of the neural network on CIFAR_100 is: 88.40 %
# Accuracy of the neural network on CIFAR_100 is: 83.60 %
# Epoch: 63, Iteration:     0, Loss: 0.345
# Accuracy of the neural network on CIFAR_100 is: 85.92 %
# Accuracy of the neural network on CIFAR_100 is: 83.00 %
# Epoch: 64, Iteration:     0, Loss: 0.453
# Accuracy of the neural network on CIFAR_100 is: 88.64 %
# Accuracy of the neural network on CIFAR_100 is: 83.20 %
# Epoch: 65, Iteration:     0, Loss: 0.241
# Accuracy of the neural network on CIFAR_100 is: 86.84 %
# Accuracy of the neural network on CIFAR_100 is: 84.00 %
# Epoch: 66, Iteration:     0, Loss: 0.360
# Accuracy of the neural network on CIFAR_100 is: 89.28 %
# Accuracy of the neural network on CIFAR_100 is: 85.40 %
# Epoch: 67, Iteration:     0, Loss: 0.267
# Accuracy of the neural network on CIFAR_100 is: 88.08 %
# Accuracy of the neural network on CIFAR_100 is: 84.40 %
# Epoch: 68, Iteration:     0, Loss: 0.299
# Accuracy of the neural network on CIFAR_100 is: 88.92 %
# Accuracy of the neural network on CIFAR_100 is: 85.80 %
# Epoch: 69, Iteration:     0, Loss: 0.337
# Accuracy of the neural network on CIFAR_100 is: 88.08 %
# Accuracy of the neural network on CIFAR_100 is: 82.60 %
# Epoch: 70, Iteration:     0, Loss: 0.316
# Accuracy of the neural network on CIFAR_100 is: 88.68 %
# Accuracy of the neural network on CIFAR_100 is: 84.60 %
# Epoch: 71, Iteration:     0, Loss: 0.327
# Accuracy of the neural network on CIFAR_100 is: 92.36 %
# Accuracy of the neural network on CIFAR_100 is: 87.00 %
# Epoch: 72, Iteration:     0, Loss: 0.223
# Accuracy of the neural network on CIFAR_100 is: 92.04 %
# Accuracy of the neural network on CIFAR_100 is: 86.20 %
# Epoch: 73, Iteration:     0, Loss: 0.190
# Accuracy of the neural network on CIFAR_100 is: 92.36 %
# Accuracy of the neural network on CIFAR_100 is: 87.20 %
# Epoch: 74, Iteration:     0, Loss: 0.170
# Accuracy of the neural network on CIFAR_100 is: 92.84 %
# Accuracy of the neural network on CIFAR_100 is: 86.80 %
# Epoch: 75, Iteration:     0, Loss: 0.175
# Accuracy of the neural network on CIFAR_100 is: 93.48 %
# Accuracy of the neural network on CIFAR_100 is: 87.00 %
# Epoch: 76, Iteration:     0, Loss: 0.247
# Accuracy of the neural network on CIFAR_100 is: 94.20 %
# Accuracy of the neural network on CIFAR_100 is: 86.20 %
# Epoch: 77, Iteration:     0, Loss: 0.124
# Accuracy of the neural network on CIFAR_100 is: 93.40 %
# Accuracy of the neural network on CIFAR_100 is: 85.60 %
# Epoch: 78, Iteration:     0, Loss: 0.197
# Accuracy of the neural network on CIFAR_100 is: 93.36 %
# Accuracy of the neural network on CIFAR_100 is: 86.80 %
# Epoch: 79, Iteration:     0, Loss: 0.283
# Accuracy of the neural network on CIFAR_100 is: 94.56 %
# Accuracy of the neural network on CIFAR_100 is: 86.60 %
# Epoch: 80, Iteration:     0, Loss: 0.131
# Accuracy of the neural network on CIFAR_100 is: 94.32 %
# Accuracy of the neural network on CIFAR_100 is: 86.20 %
# Epoch: 81, Iteration:     0, Loss: 0.134
# Accuracy of the neural network on CIFAR_100 is: 94.28 %
# Accuracy of the neural network on CIFAR_100 is: 86.00 %
# Epoch: 82, Iteration:     0, Loss: 0.141
# Accuracy of the neural network on CIFAR_100 is: 94.36 %
# Accuracy of the neural network on CIFAR_100 is: 87.00 %
# Epoch: 83, Iteration:     0, Loss: 0.089
# Accuracy of the neural network on CIFAR_100 is: 94.28 %
# Accuracy of the neural network on CIFAR_100 is: 86.20 %
# Epoch: 84, Iteration:     0, Loss: 0.112
# Accuracy of the neural network on CIFAR_100 is: 94.56 %
# Accuracy of the neural network on CIFAR_100 is: 85.60 %
# Epoch: 85, Iteration:     0, Loss: 0.206
# Accuracy of the neural network on CIFAR_100 is: 95.48 %
# Accuracy of the neural network on CIFAR_100 is: 86.40 %
# Epoch: 86, Iteration:     0, Loss: 0.127
# Accuracy of the neural network on CIFAR_100 is: 93.84 %
# Accuracy of the neural network on CIFAR_100 is: 85.60 %
# Epoch: 87, Iteration:     0, Loss: 0.196
# Accuracy of the neural network on CIFAR_100 is: 95.08 %
# Accuracy of the neural network on CIFAR_100 is: 85.80 %
# Epoch: 88, Iteration:     0, Loss: 0.168
# Accuracy of the neural network on CIFAR_100 is: 94.96 %
# Accuracy of the neural network on CIFAR_100 is: 87.00 %
# Epoch: 89, Iteration:     0, Loss: 0.131
# Accuracy of the neural network on CIFAR_100 is: 94.60 %
# Accuracy of the neural network on CIFAR_100 is: 86.80 %
# Epoch: 90, Iteration:     0, Loss: 0.212
# Accuracy of the neural network on CIFAR_100 is: 94.72 %
# Accuracy of the neural network on CIFAR_100 is: 87.20 %
# Epoch: 91, Iteration:     0, Loss: 0.120
# Accuracy of the neural network on CIFAR_100 is: 94.80 %
# Accuracy of the neural network on CIFAR_100 is: 87.60 %
# Epoch: 92, Iteration:     0, Loss: 0.134
# Accuracy of the neural network on CIFAR_100 is: 94.72 %
# Accuracy of the neural network on CIFAR_100 is: 87.80 %
# Epoch: 93, Iteration:     0, Loss: 0.146
# Accuracy of the neural network on CIFAR_100 is: 95.08 %
# Accuracy of the neural network on CIFAR_100 is: 87.60 %
# Epoch: 94, Iteration:     0, Loss: 0.105
# Accuracy of the neural network on CIFAR_100 is: 95.04 %
# Accuracy of the neural network on CIFAR_100 is: 87.80 %
# Epoch: 95, Iteration:     0, Loss: 0.116
# Accuracy of the neural network on CIFAR_100 is: 94.88 %
# Accuracy of the neural network on CIFAR_100 is: 87.80 %
# Epoch: 96, Iteration:     0, Loss: 0.086
# Accuracy of the neural network on CIFAR_100 is: 94.96 %
# Accuracy of the neural network on CIFAR_100 is: 87.40 %
# Epoch: 97, Iteration:     0, Loss: 0.079
# Accuracy of the neural network on CIFAR_100 is: 95.48 %
# Accuracy of the neural network on CIFAR_100 is: 88.00 %
# Epoch: 98, Iteration:     0, Loss: 0.177
# Accuracy of the neural network on CIFAR_100 is: 95.20 %
# Accuracy of the neural network on CIFAR_100 is: 88.00 %
# Epoch: 99, Iteration:     0, Loss: 0.065
# Accuracy of the neural network on CIFAR_100 is: 95.20 %
# Accuracy of the neural network on CIFAR_100 is: 87.80 %
# Epoch: 100, Iteration:     0, Loss: 0.138
# Accuracy of the neural network on CIFAR_100 is: 95.04 %
# Accuracy of the neural network on CIFAR_100 is: 87.80 %
# Plotting in:  /content/drive/MyDrive/Zavrsni/plots_DMC/train_plots/training_plot_5_1.png
# Consolidation stage:
# =================
# Epoch: 1, Iteration:     0, Loss: 17.073
# Epoch: 1, Iteration:    50, Loss: 11.950
# Epoch: 1, Iteration:   100, Loss: 10.005
# Accuracy of the neural network on CIFAR_100 is: 20.00 %
# Accuracy of the neural network on CIFAR_100 is: 20.00 %
# Epoch: 2, Iteration:     0, Loss: 7.701
# Epoch: 2, Iteration:    50, Loss: 7.356
# Epoch: 2, Iteration:   100, Loss: 7.162
# Accuracy of the neural network on CIFAR_100 is: 30.04 %
# Accuracy of the neural network on CIFAR_100 is: 34.80 %
# Epoch: 3, Iteration:     0, Loss: 6.612
# Epoch: 3, Iteration:    50, Loss: 6.136
# Epoch: 3, Iteration:   100, Loss: 6.005
# Accuracy of the neural network on CIFAR_100 is: 35.68 %
# Accuracy of the neural network on CIFAR_100 is: 41.20 %
# Epoch: 4, Iteration:     0, Loss: 5.123
# Epoch: 4, Iteration:    50, Loss: 5.457
# Epoch: 4, Iteration:   100, Loss: 5.355
# Accuracy of the neural network on CIFAR_100 is: 35.96 %
# Accuracy of the neural network on CIFAR_100 is: 42.80 %
# Epoch: 5, Iteration:     0, Loss: 4.694
# Epoch: 5, Iteration:    50, Loss: 5.220
# Epoch: 5, Iteration:   100, Loss: 4.989
# Accuracy of the neural network on CIFAR_100 is: 40.36 %
# Accuracy of the neural network on CIFAR_100 is: 45.40 %
# Epoch: 6, Iteration:     0, Loss: 4.009
# Epoch: 6, Iteration:    50, Loss: 4.546
# Epoch: 6, Iteration:   100, Loss: 4.547
# Accuracy of the neural network on CIFAR_100 is: 41.44 %
# Accuracy of the neural network on CIFAR_100 is: 48.00 %
# Epoch: 7, Iteration:     0, Loss: 4.496
# Epoch: 7, Iteration:    50, Loss: 4.375
# Epoch: 7, Iteration:   100, Loss: 4.333
# Accuracy of the neural network on CIFAR_100 is: 45.08 %
# Accuracy of the neural network on CIFAR_100 is: 57.40 %
# Epoch: 8, Iteration:     0, Loss: 3.480
# Epoch: 8, Iteration:    50, Loss: 4.256
# Epoch: 8, Iteration:   100, Loss: 4.153
# Accuracy of the neural network on CIFAR_100 is: 49.20 %
# Accuracy of the neural network on CIFAR_100 is: 59.00 %
# Epoch: 9, Iteration:     0, Loss: 4.185
# Epoch: 9, Iteration:    50, Loss: 3.930
# Epoch: 9, Iteration:   100, Loss: 3.862
# Accuracy of the neural network on CIFAR_100 is: 55.72 %
# Accuracy of the neural network on CIFAR_100 is: 67.00 %
# Epoch: 10, Iteration:     0, Loss: 3.262
# Epoch: 10, Iteration:    50, Loss: 3.624
# Epoch: 10, Iteration:   100, Loss: 3.680
# Accuracy of the neural network on CIFAR_100 is: 58.80 %
# Accuracy of the neural network on CIFAR_100 is: 70.60 %
# Epoch: 11, Iteration:     0, Loss: 3.585
# Epoch: 11, Iteration:    50, Loss: 3.520
# Epoch: 11, Iteration:   100, Loss: 3.500
# Accuracy of the neural network on CIFAR_100 is: 63.64 %
# Accuracy of the neural network on CIFAR_100 is: 72.00 %
# Epoch: 12, Iteration:     0, Loss: 3.459
# Epoch: 12, Iteration:    50, Loss: 3.342
# Epoch: 12, Iteration:   100, Loss: 3.328
# Accuracy of the neural network on CIFAR_100 is: 64.96 %
# Accuracy of the neural network on CIFAR_100 is: 72.80 %
# Epoch: 13, Iteration:     0, Loss: 3.168
# Epoch: 13, Iteration:    50, Loss: 3.137
# Epoch: 13, Iteration:   100, Loss: 3.169
# Accuracy of the neural network on CIFAR_100 is: 69.16 %
# Accuracy of the neural network on CIFAR_100 is: 74.20 %
# Epoch: 14, Iteration:     0, Loss: 3.142
# Epoch: 14, Iteration:    50, Loss: 3.053
# Epoch: 14, Iteration:   100, Loss: 3.008
# Accuracy of the neural network on CIFAR_100 is: 62.12 %
# Accuracy of the neural network on CIFAR_100 is: 71.60 %
# Epoch: 15, Iteration:     0, Loss: 2.557
# Epoch: 15, Iteration:    50, Loss: 2.910
# Epoch: 15, Iteration:   100, Loss: 2.852
# Accuracy of the neural network on CIFAR_100 is: 64.76 %
# Accuracy of the neural network on CIFAR_100 is: 73.40 %
# Epoch: 16, Iteration:     0, Loss: 2.826
